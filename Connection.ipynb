# %% [markdown]
# <a href="https://colab.research.google.com/github/RealRay620/Kaggle_SQL_EDA/blob/main/Connection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#==================================================
#                     IMPORTS
import os
from google.colab import userdata
import duckdb as duckdb

#==================================================

# %%
#==================================================
#                   INSTALL KAGGLE
# !pip install Kaggle --quiet
# !pip install -q --upgrade kaggle==2.0.1 - upgrage to the latest version
# !pip install DuckDB --upgrade

#==================================================

# %%
#==================================================
#    CONNECTION TO THE KAGGLE DATASET

os.environ['KAGGLE_USERNAME'] = userdata.get('user_name')
os.environ['KAGGLE_KEY'] = userdata.get('kaggle_1').strip()

#==================================================

# %%
#==================================================
#    CONNECTION TESTING

print(os.environ['KAGGLE_USERNAME'])
print(os.environ['KAGGLE_KEY'][:5])  # only preview for safety
# !kaggle datasets list # Test to ensure connection is made
# Out:
# ryanlandey
# KGAT_
# ref                                                            title                                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------  --------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# nalisha/job-salary-prediction-dataset                          Job Salary Prediction Dataset                          3144815  2026-03-16 19:54:33.843000          11023        269                1
# algozee/teenager-menthal-healy                                 Social Media Impact on Teen Mental Health                16190  2026-04-05 08:04:21.823000           2247         54                1
# ...

# %%
#===================  TESTING  =======================
print(os.environ.get("KAGGLE_USERNAME"))
print(os.environ.get("KAGGLE_KEY") is not None)
# !kaggle --version
# Out:
# ryanlandey
# True
# Kaggle CLI 2.0.1

# %%
# !kaggle competitions list # not sure why this is not working need to fix this
# Out:
# 401 Client Error: Unauthorized for url: https://api.kaggle.com/v1/competitions.CompetitionApiService/ListCompetitions

# %%
#==================== Search for files =======================
# !kaggle datasets list -s 'bvanntruong/housing-sql-project' # used to search kaggle database, to ensure that I am downloading the correct file
# Out:
# ref                              title                        size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -------------------------------  ---------------------  ----------  --------------------------  -------------  ---------  ---------------
# bvanntruong/housing-sql-project  Housing - SQL Project     2100611  2023-06-12 23:22:14.150000           3685         49  0.88235295

# %%
#=======================================================
# Download and unziping files
# !kaggle datasets download bvanntruong/housing-sql-project # used to download file into Colab
# !unzip housing-sql-project.zip #unzip the files
# Out:
# Dataset URL: https://www.kaggle.com/datasets/bvanntruong/housing-sql-project
# License(s): unknown
# ...
# 100% 2.00M/2.00M [00:01<00:00, 1.34MB/s]

# %%
#=============================================================
#     Testing if it works with python
#import pandas as pd
#df = pd.read_csv('Netflix Shows.csv', encoding='latin1')
#df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
#=============================================================
#     duckdb connection reading relational database

duckdb.read_csv('Nashville Housing.csv', header = False)
# Out:
# ┌───────────┬─────────────────┬──────────────────────────┬───────────────────────────────────────┬────────────────────┬───────────┬──────────────────┬──────────────┬───────────────────────────────────────┬───────────────────────────────────────────┬──────────┬───────────────────────────┬───────────┬───────────────┬────────────┬───────────┬──────────┬──────────┬──────────┐
# │ column00  │    column01     │         column02         │               column03                │      column04      │ column05  │     column06     │   column07   │               column08                │                 column09                  │ column10 │         column11          │ column12  │   column13    │  column14  │ column15  │ column16 │ column17 │ column18 │
# ...
