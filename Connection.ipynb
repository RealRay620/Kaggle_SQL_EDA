# %% [markdown]
# <a href="https://colab.research.google.com/github/RealRay620/Kaggle_SQL_EDA/blob/main/Connection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#==================================================
#                     IMPORTS
import os
from google.colab import userdata

#==================================================

# %%
#==================================================
#                   INSTALL KAGGLE
# !pip install Kaggle --quiet
# !pip install -q --upgrade kaggle==2.0.1 - upgrage to the latest version

#==================================================

# %%
#==================================================
#    CONNECTION TO THE KAGGLE DATASET

os.environ['KAGGLE_USERNAME'] = userdata.get('user_name')
os.environ['KAGGLE_KEY'] = userdata.get('kaggle_1').strip()

#==================================================

# %%
print(os.environ['KAGGLE_USERNAME'])
print(os.environ['KAGGLE_KEY'][:5])  # only preview for safety
# Out:
# ryanlandey
# KGAT_

# %%
# !kaggle datasets list
# Out:
# ref                                                              title                                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ---------------------------------------------------------------  --------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# nalisha/job-salary-prediction-dataset                            Job Salary Prediction Dataset                          3144815  2026-03-16 19:54:33.843000          10751        264                1
# algozee/teenager-menthal-healy                                   Social Media Impact on Teen Mental Health                16190  2026-04-05 08:04:21.823000           1980         53                1
# sumeakash/impact-of-social-media-on-health                       Impact of Social Media on Health                         18598  2026-04-05 06:53:55.953000           2646         67        0.9411765
# upcoderr/car-specifications-dataset                              Car Specifications Dataset                               37327  2026-04-09 14:08:32.500000            647         27                1
# belbino/global-fuel-prices-20202026                              Global Fuel Prices 2020–2026                            420762  2026-04-07 06:43:27.817000           1340         30                1
# rifatalam3/coffee-revenue-dataset                                Coffee Revenue Dataset                                   38970  2026-04-07 05:32:05.120000           1061         35                1
# ihasan88/customer-behavior-and-churn-prediction-dataset          Customer Behavior and Churn Prediction Dataset           28792  2026-04-09 04:40:08.707000            502         25                1
# borovai0/student-performance-analytics-dataset                   Student Performance Analytics Dataset                   264103  2026-04-01 19:54:36.470000           1998         43                1
# rifatalam3/gold-price-trends                                     Gold Price Trends                                        85994  2026-04-06 14:00:56.563000           1119         39                1
# sumeakash/ai-impact-on-job-sector                                AI Impact on Job Sector                                  49335  2026-04-09 18:27:48.813000            706         24        0.9411765
# ssssws/chocolate-sales-dataset-2023-2024                         Chocolate Sales Dataset 2023 - 2024                   24420255  2026-03-07 04:58:02.387000          13861        216                1
# kienngx/nemotron-30b-competition-trainingdata-cot-labels         Nemotron-30B competition trainingdata (CoT+labels)     3903114  2026-03-24 01:42:23.850000            960         38                1
# guriya79/how-ai-is-changing-student-life                         How AI is Changing Student Life                           1545  2026-03-27 16:47:08.317000           1832         55                1
# minahilfatima12328/consumer-shopping-trends-analysis             Consumer Shopping Trends Analysis                       354898  2026-03-26 12:45:19.030000           2156         39                1
# jawadaahmed/mobile-price-dataset                                 Mobile Price Dataset                                       596  2026-04-06 16:00:00.813000            561         25                1
# ihasan88/student-performance-dataset                             Student Performance Dataset                              19502  2026-04-08 16:31:57.580000            823         28                1
# mdmahfuzsumon/spotify-track-metadata-dataset-for-data-science    Spotify Track Metadata Dataset for Data Science         619333  2026-04-12 16:10:15.267000            630         30                1
# asifxzaman/university-students-performance-and-study-habits2026  University Students Performance & Study Habits2026      316783  2026-04-01 16:51:08.913000            888         28                1
# upcoderr/student-performance-analytics-dataset                   Student Performance Analytics Dataset                   264111  2026-04-09 12:53:04.830000            431         28                1
# asifxzaman/e-commerce-behavior-dataset8000-users                 E-Commerce Behavior Dataset(8000 Users)                 151485  2026-03-31 16:43:13.683000           1821         53                1

# %%
print(os.environ.get("KAGGLE_USERNAME"))
print(os.environ.get("KAGGLE_KEY") is not None)
# !kaggle --version
# Out:
# ryanlandey
# True
# Kaggle CLI 2.0.1

# %%
#  !kaggle competitions list
# Out:
# 401 Client Error: Unauthorized for url: https://api.kaggle.com/v1/competitions.CompetitionApiService/ListCompetitions

# %%
# !kaggle datasets list -s 'chasewillden/netflix-shows' # used to search kaggle database, to ensure that I am downloading the correct file
# Out:
# ref                         title                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# --------------------------  ------------------  ----------  --------------------------  -------------  ---------  ---------------
# chasewillden/netflix-shows  1000 Netflix Shows       10825  2017-06-11 03:30:16.350000          12756        145  0.8235294

# %%
# !kaggle datasets download chasewillden/netflix-shows
# Out:
# Dataset URL: https://www.kaggle.com/datasets/chasewillden/netflix-shows
# License(s): CC0-1.0
# Downloading netflix-shows.zip to /content
# 100% 10.6k/10.6k [00:00<00:00, 21.0MB/s]

# %%
# !unzip netflix-shows.zip
# Out:
# Archive:  netflix-shows.zip
# replace Netflix Shows.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Netflix Shows.csv

# %%
import pandas as pd
df = pd.read_csv('Netflix Shows.csv', encoding='latin1')
df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80
