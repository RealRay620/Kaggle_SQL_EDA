# %% [markdown]
# <a href="https://colab.research.google.com/github/RealRay620/Kaggle_SQL_EDA/blob/main/Connection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#==================================================
# Imports
import os
import json
from google.colab import userdata


#==================================================

# %%
#==================================================
#       INSTALL KAGGLE
# !pip install Kaggle --quiet

#==================================================

# %%
import os
import json
from google.colab import userdata

#    Connection to the Kaggle database

kaggle_config = userdata.get('kaggle_1')
# kaggle_config = json.loads(kaggle_config) # This line caused the error and is not needed.

# Now, kaggle_config holds the string value directly.
# If you need to write it to a file, you can do so like this:
# with open('kaggle.json', 'w') as f:
#    json.dump({"username": "your_kaggle_username", "key": kaggle_config}, f)
# For direct use, you might set an environment variable or use it as is.
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /tmp/ipykernel_3353/2650202032.py in <cell line: 0>()
#       2
#       3 kaggle_config = userdata.get('kaggle_1')
# ----> 4 kaggle_config = json.loads(kaggle_config)
#
# /usr/lib/python3.12/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /usr/lib/python3.12/json/decoder.py in decode(self, s, _w)
#     336
#     337         """
# --> 338         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     339         end = _w(s, end).end()
#     340         if end != len(s):
#
# ...

# %%
# Create kaggle directory

# !mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
ls -ltr ~/.kaggle
# Out:
# total 0
